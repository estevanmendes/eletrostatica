# %%
from laplace_cartesian_v1 import *

# %%
dim=10
rounds=10

# %%
capacitor=capacitor_rectangle(dim,dim,realism=True)

# %%
cem=np.ones(dim)*100
cem_2=np.ones(dim+2)*100

zero=np.zeros(dim)
capacitor.contour(cem,-cem,zero,zero)

# %%
resultado=capacitor.run(rounds=100)
capacitor.plot2d()
# Out:
# [ 100. -100.  100. -100.  100. -100.  100. -100.  100. -100.  100. -100.
#   100. -100.  100. -100.  100. -100.  100. -100.]
# [ 100. -100.  100. -100.  100. -100.  100. -100.  100. -100.  100. -100.
#   100. -100.  100. -100.  100. -100.  100. -100.]
# [ 100. -100.  100. -100.  100. -100.  100. -100.  100. -100.  100. -100.
#   100. -100.  100. -100.  100. -100.  100. -100.]
# [ 100. -100.  100. -100.  100. -100.  100. -100.  100. -100.  100. -100.
#   100. -100.  100. -100.  100. -100.  100. -100.]
# [ 100. -100.  100. -100.  100. -100.  100. -100.  100. -100.  100. -100.
#   100. -100.  100. -100.  100. -100.  100. -100.]
# [ 100. -100.  100. -100.  100. -100.  100. -100.  100. -100.  100. -100.
#   100. -100.  100. -100.  100. -100.  100. -100.]
# [ 100. -100.  100. -100.  100. -100.  100. -100.  100. -100.  100. -100.
#   100. -100.  100. -100.  100. -100.  100. -100.]
# [ 100. -100.  100. -100.  100. -100.  100. -100.  100. -100.  100. -100.
# ...

# %%
capacitor.plot3d()

# %%
capacitor.dataframe('dados_ver')
# Out:
# 'csv file saved'

# %%
a=np.zeros((4,4))

# %%
a[2:4,3]=1

# %%
a[np.nonzero(a)]
# Out:
# array([1., 1.])
